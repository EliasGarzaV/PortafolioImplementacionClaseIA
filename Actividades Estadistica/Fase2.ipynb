# %% [markdown]
# # Fase #2: Construcción de un modelo estadístico base
#
# Elías Garza Valdés
# A01284041

# %%
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np

# %% [markdown]
# ## Leyendo los datos

# %%
df = pd.read_csv(r'../Data/precios_autos.csv')
df.head()
# Out:
#    symboling                   CarName fueltype      carbody drivewheel  \
# 0          3        alfa-romero giulia      gas  convertible        rwd
# 1          3       alfa-romero stelvio      gas  convertible        rwd
# 2          1  alfa-romero Quadrifoglio      gas    hatchback        rwd
# 3          2               audi 100 ls      gas        sedan        fwd
# 4          2                audi 100ls      gas        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  carheight  ...  enginetype  \
# 0          front       88.6      168.8      64.1       48.8  ...        dohc
# 1          front       88.6      168.8      64.1       48.8  ...        dohc
# 2          front       94.5      171.2      65.5       52.4  ...        ohcv
# 3          front       99.8      176.6      66.2       54.3  ...         ohc
# 4          front       99.4      176.6      66.4       54.3  ...         ohc
#
#   cylindernumber enginesize  stroke  compressionratio  horsepower  peakrpm  \
# 0           four        130    2.68               9.0         111     5000
# 1           four        130    2.68               9.0         111     5000
# 2            six        152    3.47               9.0         154     5000
# 3           four        109    3.40              10.0         102     5500
# 4           five        136    3.40               8.0         115     5500
#
#    citympg  highwaympg    price
# 0       21          27  13495.0
# 1       21          27  16500.0
# 2       19          26  16500.0
# 3       24          30  13950.0
# 4       18          22  17450.0
#
# [5 rows x 21 columns]

# %%
df = df.drop(columns = ['CarName', 'enginelocation'])
df = pd.get_dummies(df)

# %%
sns.heatmap(df.corr())
plt.show()

# %%
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity
from factor_analyzer.factor_analyzer import calculate_kmo

chi_square_value, p_value = calculate_bartlett_sphericity(df)
# kmo_all, kmo_model = calculate_kmo(df)

print("Bartlett’s Test p-value:", p_value)
# print("KMO:", kmo_model)
# Out:
# Bartlett’s Test p-value: 0.0

# %%
from factor_analyzer import FactorAnalyzer

fa = FactorAnalyzer(rotation="varimax", n_factors=6, method='principal')  # Assuming you want 3 factors, adjust as necessary
fa.fit(df.drop(columns = 'price'))

loadings = fa.loadings_
print("Factor Loadings:\n", loadings)
# Out:
# Factor Loadings:
#  [[-4.67504593e-02 -1.78607445e-01  3.15681258e-01  7.57456610e-02
#   -5.97494171e-01  2.42511792e-01]
#  [ 5.86643605e-01  3.13061617e-01 -8.58361801e-02  4.11099699e-02
#    6.29612703e-01 -1.11137864e-01]
#  [ 7.37144994e-01  1.84570630e-01 -8.43551616e-02  3.47042192e-02
#    5.34263243e-01 -1.17579041e-01]
#  [ 7.51333774e-01  2.04878571e-01 -3.03850388e-02  1.46485117e-01
#    4.29483043e-01  2.11877419e-01]
#  [ 4.31354986e-02  2.81668600e-01 -2.23634394e-01 -2.24531526e-01
#    6.97290278e-01 -2.04518564e-01]
#  [ 8.91445748e-01  2.02041000e-01 -5.55501029e-02  9.39834906e-03
#    3.14504220e-01  5.98608456e-02]
#  [ 8.81042089e-01  7.32499709e-02 -2.94432946e-01  1.20791065e-01
#    2.74768223e-02  1.99283140e-01]
#  [ 5.97071179e-02  1.33501439e-01  3.90564377e-02  7.34148607e-01
#    1.36326632e-01  4.05742381e-02]
#  [-5.17771455e-02  9.48624657e-01  5.27320677e-03  1.43967139e-01
#    2.93410411e-02 -2.34386862e-02]
#  [ 8.76463690e-01 -2.01455250e-01 -3.40630064e-02  6.37466788e-02
#   -6.19750401e-02  1.89178325e-01]
#  [-6.13962811e-02 -5.82852004e-01  3.15905683e-01  1.30087106e-01
#   -1.62457649e-01 -9.27323039e-02]
#  [-8.27397563e-01  3.19437014e-01 -1.74438574e-01  2.73695112e-02
#   -2.29874336e-01 -3.71146844e-02]
#  [-8.42197305e-01  2.49134692e-01 -1.55110909e-01  6.76268367e-02
#   -2.73205283e-01 -2.88253116e-02]
#  [-1.27116484e-02  9.52298574e-01  4.19325993e-03  1.50457621e-01
#    8.73641032e-02 -1.27909720e-02]
#  [ 1.27116484e-02 -9.52298574e-01 -4.19325993e-03 -1.50457621e-01
#   -8.73641032e-02  1.27909720e-02]
#  [ 1.76798374e-01 -1.35860764e-02 -5.87399260e-02 -1.35670872e-01
#   -3.60682086e-01  7.75061492e-03]
#  [ 1.81001640e-01  7.10630245e-02 -4.55976664e-02 -2.10181061e-02
#   -1.49293672e-01  2.13108991e-01]
#  [-2.20151299e-01 -1.90644527e-01  3.36932985e-01  1.24969882e-01
#   -3.59975348e-01  4.41971895e-01]
#  [ 9.50194710e-02  1.43876268e-01 -2.95121466e-01  2.27530827e-01
#    2.01890582e-01 -5.27384084e-01]
#  [-2.40518244e-02  2.18160781e-02  1.90114740e-02 -4.45738122e-01
#    4.87930576e-01  3.36227912e-02]
#  [-6.00726773e-02 -8.17890262e-02  1.67348435e-02 -5.43020683e-01
#    2.09631356e-01  1.16959971e-01]
#  [-7.15137463e-01 -1.66125582e-01 -2.15669486e-01  2.96311477e-01
#   -4.96927272e-02  7.38159210e-02]
#  [ 7.54918773e-01  2.04140482e-01  2.12883452e-01 -7.18993358e-02
#   -3.82345279e-02 -1.24903728e-01]
#  [ 3.46234768e-01 -8.22976505e-02 -1.25626932e-03 -1.54601567e-02
#   -3.03301556e-01 -3.75081824e-01]
#  [ 1.23024513e-01 -5.87652398e-03 -2.20736175e-02 -4.62954684e-03
#   -1.91687897e-04  5.32257640e-01]
#  [ 1.21766945e-01  4.21189075e-01  8.41369834e-02 -3.26488080e-01
#    1.65552194e-01 -1.67849968e-01]
#  [-5.70882072e-01 -1.11772270e-01 -1.62347061e-01  5.81012075e-01
#    2.75137195e-01  2.22823178e-02]
#  [-4.35154281e-03 -3.85746771e-02 -8.03096053e-02 -7.07814719e-01
#   -1.63837416e-01  4.94291865e-02]
#  [ 5.27384345e-01 -5.94188988e-02 -2.15555683e-01  9.97545244e-03
#   -1.67368261e-01  2.80859434e-01]
#  [ 7.19012649e-02 -3.28424370e-02  9.27331132e-01  1.57396487e-02
#   -5.39792112e-02 -6.72773729e-03]
#  [ 3.79205826e-01  5.69599146e-03 -1.66679848e-01 -2.44358625e-02
#    3.98884611e-02  6.17204453e-01]
#  [ 1.44936464e-01  1.11255983e-01  8.56362482e-02  2.31413767e-01
#    3.99997333e-01  1.54080606e-01]
#  [-7.30984700e-01 -1.41498927e-02 -1.77446521e-01 -1.41270356e-01
#    8.19556931e-02 -1.26679171e-01]
#  [ 6.08458206e-01 -7.19389587e-02 -1.25451119e-01  5.32756819e-02
#   -3.11626666e-01 -2.56203776e-01]
#  [-1.10058517e-01  1.23386327e-01  1.52720230e-02 -1.47176592e-01
#   -2.24304051e-01  1.66066170e-02]
#  [ 2.28148532e-01 -1.39420380e-02 -1.22782254e-01  2.16123840e-02
#   -1.03276009e-01  7.26783350e-02]
#  [ 7.19012649e-02 -3.28424370e-02  9.27331132e-01  1.57396487e-02
#   -5.39792112e-02 -6.72773729e-03]]

# %%
var, prop_var, cum_var = fa.get_factor_variance()

print("Variance:", var)
print("Proportional Variance:", prop_var)
print("Cumulative Variance:", cum_var)
# Out:
# Variance: [8.30419682 3.98313596 2.61488204 2.44432714 3.19246586 1.84493143]
# Proportional Variance: [0.22443775 0.10765232 0.07067249 0.0660629  0.08628286 0.04986301]
# Cumulative Variance: [0.22443775 0.33209008 0.40276256 0.46882546 0.55510832 0.60497133]

# %%
ev, v = fa.get_eigenvalues()

import matplotlib.pyplot as plt

plt.scatter(range(1, df.shape[1]), ev)
plt.plot(range(1, df.shape[1]), ev)
plt.title("Scree Plot")
plt.xlabel("Factors")
plt.ylabel("Eigenvalue")
plt.grid()
plt.show()

# %%
import seaborn as sns
fa_loading_matrix = pd.DataFrame(fa.loadings_, columns=['FA{}'.format(i) for i in range(0, 6)], index=df.drop(columns = 'price').columns)


plt.figure(figsize=(25,5))

ax = sns.heatmap(fa_loading_matrix.T, 
                 vmin=-1, vmax=1, center=0,
                 cmap=sns.diverging_palette(220, 20, n=200),
                 square=True, annot=True, fmt='.2f', cbar = False)

ax.set_yticklabels(
    ax.get_yticklabels(),
    rotation=0)
# Out:
# [Text(0, 0.5, 'FA0'),
#  Text(0, 1.5, 'FA1'),
#  Text(0, 2.5, 'FA2'),
#  Text(0, 3.5, 'FA3'),
#  Text(0, 4.5, 'FA4'),
#  Text(0, 5.5, 'FA5')]

# %% [markdown]
# Queremos ver que variables son importantes al momento de decidir el precio de un automovil. Por lo tanto, vamos a generar una regresion lineal con las variables para ver si importan al momento de decidir el precio de un automovil.
#
# Ironicamente, la parte más facil será generar el modelo lo cual haremos a continuación. Despues toca verificar el modelo lo cual ya empieza a ser más complejo.

# %%
from sklearn.linear_model import LinearRegression, SGDRegressor
model = LinearRegression()
model.fit(df.drop(columns = 'price'), df['price'])
# Out:
# LinearRegression()

# %%
[model_stat.intercept_] +  list(model_stat.coef_)
# Out:
# [-46298.35495356047,
#  -47.150587186348055,
#  18.577086953572113,
#  -82.2077841717521,
#  607.5253710795893,
#  186.7355225881091,
#  3.515715103081931,
#  97.74817546947392,
#  -4329.700969603384,
#  -243.42650451343053,
#  45.58393961205683,
#  2.3102647699686853,
#  -155.79099865984054,
#  225.85765630328902,
#  3073.2867269575963,
#  -3073.2867269553703,
#  2923.609502265532,
#  -300.1558218917708,
#  -1076.6219209846784,
#  -231.47763349034625,
#  -1315.3541259112662,
#  -193.57422758204194,
#  -218.28821859180644,
#  411.8624461753853,
#  1951.755835812602,
#  -13838.964525600866,
#  3501.0289830243228,
#  5804.986774822784,
#  4254.772920402167,
#  -4435.1756958764445,
#  2761.595707410821,
#  8719.804339560087,
#  -2902.140337015666,
#  -5144.752759285279,
#  -214.72897998675813,
#  1418.8828720638387,
#  -4638.660842755951,
#  2761.5957074110174]

# %%
y_pred = model.predict(df.drop(columns = 'price'))
residuals = df['price'] - y_pred
# Out:
# 0      -267.261957
# 1      2737.738043
# 2      4922.835020
# 3      3403.164879
# 4       -36.918732
#           ...
# 200   -2021.972000
# 201   -2108.410803
# 202    2414.195364
# 203   -1983.482353
# 204    3425.708313
# Name: price, Length: 205, dtype: float64

# %% [markdown]
# Ahora vamos a revisar si los residuos forman una distribución normal, validando asi el modelo.

# %%
plt.hist(residuals, bins=30)
plt.xlabel('Residual')
plt.ylabel('Frequency')
plt.title('Histogram of Residuals')
plt.show()

# %%
sm.qqplot(residuals, line='s')

# Add title and labels
plt.title(f"QQ Plot: Residuals")
plt.xlabel("Theoretical Quantiles")
plt.ylabel("Sample Quantiles")

# Display the plot
plt.show()
result = stats.anderson(residuals)
print("Is data normally distributed:", result.statistic < result.critical_values[1],
        'via Anderson-Darling test with significance of:' ,100 - result.significance_level[1], '%')

data_standardized = (residuals - np.mean(residuals)) / np.std(residuals)
# Perform the K-S test for normality
ks_statistic, ks_p_value = stats.kstest(data_standardized, 'norm')

print(f"K-S test statistic: {ks_statistic:.4f}")
print(f"P-value: {ks_p_value:.4f}")
# Out:
# Is data normally distributed: False via Anderson-Darling test with significance of: 90.0 %
# K-S test statistic: 0.0732
# P-value: 0.2115

# %%
plt.scatter(y_pred, residuals)
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.axhline(y=0, color='r', linestyle='--')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
# Initialize the scaler
scaler = StandardScaler()

# Standardize all columns
df_std = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
df_std
# Out:
#      symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0     1.743470  -1.690772  -0.426521 -0.844782  -2.020417   -0.014566
# 1     1.743470  -1.690772  -0.426521 -0.844782  -2.020417   -0.014566
# 2     0.133509  -0.708596  -0.231513 -0.190566  -0.543527    0.514882
# 3     0.938490   0.173698   0.207256  0.136542   0.235942   -0.420797
# 4     0.938490   0.107110   0.207256  0.230001   0.235942    0.516807
# ..         ...        ...        ...       ...        ...         ...
# 200  -1.476452   1.721873   1.198549  1.398245   0.728239    0.763241
# 201  -1.476452   1.721873   1.198549  1.351515   0.728239    0.949992
# 202  -1.476452   1.721873   1.198549  1.398245   0.728239    0.878757
# 203  -1.476452   1.721873   1.198549  1.398245   0.728239    1.273437
# 204  -1.476452   1.721873   1.198549  1.398245   0.728239    0.975021
#
#      enginesize    stroke  compressionratio  horsepower  ...  enginetype_ohcf  \
# 0      0.074449 -1.839377         -0.288349    0.174483  ...        -0.280976
# 1      0.074449 -1.839377         -0.288349    0.174483  ...        -0.280976
# 2      0.604046  0.685946         -0.288349    1.264536  ...        -0.280976
# 3     -0.431076  0.462183         -0.035973   -0.053668  ...        -0.280976
# 4      0.218885  0.462183         -0.540725    0.275883  ...        -0.280976
# ..          ...       ...               ...         ...  ...              ...
# 200    0.339248 -0.336970         -0.162161    0.250533  ...        -0.280976
# 201    0.339248 -0.336970         -0.364062    1.416637  ...        -0.280976
# 202    1.109571 -1.232021         -0.338824    0.757535  ...        -0.280976
# 203    0.435538  0.462183          3.244916    0.047732  ...        -0.280976
# 204    0.339248 -0.336970         -0.162161    0.250533  ...        -0.280976
#
#      enginetype_ohcv  enginetype_rotor  cylindernumber_eight  \
# 0          -0.260208         -0.141069             -0.158114
# 1          -0.260208         -0.141069             -0.158114
# 2           3.843076         -0.141069             -0.158114
# 3          -0.260208         -0.141069             -0.158114
# 4          -0.260208         -0.141069             -0.158114
# ..               ...               ...                   ...
# 200        -0.260208         -0.141069             -0.158114
# 201        -0.260208         -0.141069             -0.158114
# 202         3.843076         -0.141069             -0.158114
# 203        -0.260208         -0.141069             -0.158114
# 204        -0.260208         -0.141069             -0.158114
#
#      cylindernumber_five  cylindernumber_four  cylindernumber_six  \
# 0              -0.238120             0.537874           -0.364138
# 1              -0.238120             0.537874           -0.364138
# 2              -0.238120            -1.859172            2.746210
# 3              -0.238120             0.537874           -0.364138
# 4               4.199567            -1.859172           -0.364138
# ..                   ...                  ...                 ...
# 200            -0.238120             0.537874           -0.364138
# 201            -0.238120             0.537874           -0.364138
# 202            -0.238120            -1.859172            2.746210
# 203            -0.238120            -1.859172            2.746210
# 204            -0.238120             0.537874           -0.364138
#
#      cylindernumber_three  cylindernumber_twelve  cylindernumber_two
# 0               -0.070014              -0.070014           -0.141069
# 1               -0.070014              -0.070014           -0.141069
# 2               -0.070014              -0.070014           -0.141069
# 3               -0.070014              -0.070014           -0.141069
# 4               -0.070014              -0.070014           -0.141069
# ..                    ...                    ...                 ...
# 200             -0.070014              -0.070014           -0.141069
# 201             -0.070014              -0.070014           -0.141069
# 202             -0.070014              -0.070014           -0.141069
# 203             -0.070014              -0.070014           -0.141069
# 204             -0.070014              -0.070014           -0.141069
#
# [205 rows x 38 columns]

# %%
from sklearn.linear_model import LinearRegression, SGDRegressor
model = LinearRegression()
model.fit(df_std.drop(columns = 'price'), df_std['price'])

coef = [model.intercept_] +  list(model.coef_)
coef
# Out:
# [6.640661159910764e-16,
#  -0.0073498602470188764,
#  0.014002893766244447,
#  -0.12695454995779717,
#  0.16313554344554956,
#  0.057116132963507586,
#  0.22913970359083446,
#  0.5095221611548457,
#  -0.1699594933241983,
#  -0.12103113828949191,
#  0.22563677947640054,
#  0.1379376011942084,
#  -0.12757862320792987,
#  0.19469078175850943,
#  0.11442674246646274,
#  -0.1144267424664615,
#  0.07389458132730731,
#  0.006559583462972885,
#  -0.03013959574349561,
#  0.021202573381793804,
#  -0.03060088744382084,
#  -0.0067124222528529955,
#  -0.017668786316371067,
#  0.02086934851649655,
#  -0.04003943775896947,
#  -0.14993454759410324,
#  0.00559795896973235,
#  0.14021268921757016,
#  0.03084018372361962,
#  -0.23688240787423176,
#  0.039111318026955263,
#  0.21320126933020958,
#  -0.017175208749620578,
#  -0.149193256982277,
#  0.08391359491748743,
#  0.0324664990765902,
#  -0.020491946926574463,
#  0.03911131802695502]

# %%
y_pred = model.predict(df_std.drop(columns = 'price'))
residuals = df_std['price'] - y_pred

plt.hist(residuals, bins=30)
plt.xlabel('Residual')
plt.ylabel('Frequency')
plt.title('Histogram of Residuals')
plt.show()

# %%
sm.qqplot(residuals, line='s')

# Add title and labels
plt.title(f"QQ Plot: Residuals")
plt.xlabel("Theoretical Quantiles")
plt.ylabel("Sample Quantiles")

# Display the plot
plt.show()
result = stats.anderson(residuals)
print("Is data normally distributed:", result.statistic < result.critical_values[1],
        'via Anderson-Darling test with significance of:' ,100 - result.significance_level[1], '%')

data_standardized = (residuals - np.mean(residuals)) / np.std(residuals)
# Perform the K-S test for normality
ks_statistic, ks_p_value = stats.kstest(data_standardized, 'norm')

print(f"K-S test statistic: {ks_statistic:.4f}")
print(f"P-value: {ks_p_value:.4f}")
# Out:
# Is data normally distributed: False via Anderson-Darling test with significance of: 90.0 %
# K-S test statistic: 0.0732
# P-value: 0.2115

# %%
mod = pd.DataFrame({'Vars':df_std.drop(columns = 'price').columns, 'Coeficients':coef[1:]})
mod.sort_values(by='Coeficients', ascending=False)
# Out:
#                      Vars  Coeficients
# 6              enginesize     0.509522
# 5              curbweight     0.229140
# 9              horsepower     0.225637
# 30   cylindernumber_eight     0.213201
# 12             highwaympg     0.194691
# 3                carwidth     0.163136
# 26         enginetype_ohc     0.140213
# 10                peakrpm     0.137938
# 13        fueltype_diesel     0.114427
# 33     cylindernumber_six     0.083914
# 15    carbody_convertible     0.073895
# 4               carheight     0.057116
# 29       enginetype_rotor     0.039111
# 36     cylindernumber_two     0.039111
# 34   cylindernumber_three     0.032466
# 27        enginetype_ohcf     0.030840
# 18          carbody_sedan     0.021203
# 22         drivewheel_rwd     0.020869
# 1               wheelbase     0.014003
# 16        carbody_hardtop     0.006560
# 25           enginetype_l     0.005598
# 20         drivewheel_4wd    -0.006712
# 0               symboling    -0.007350
# 31    cylindernumber_five    -0.017175
# 21         drivewheel_fwd    -0.017669
# 35  cylindernumber_twelve    -0.020492
# 17      carbody_hatchback    -0.030140
# 19          carbody_wagon    -0.030601
# 23        enginetype_dohc    -0.040039
# 14           fueltype_gas    -0.114427
# 8        compressionratio    -0.121031
# 2               carlength    -0.126955
# 11                citympg    -0.127579
# 32    cylindernumber_four    -0.149193
# 24       enginetype_dohcv    -0.149935
# 7                  stroke    -0.169959
# 28        enginetype_ohcv    -0.236882

# %%
plt.scatter(y_pred, residuals)
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.axhline(y=0, color='r', linestyle='--')
plt.show()

# %% [markdown]
# Como podemos ver. A pesar de que sí tenemos un modelo este no cumple con nuestras supocisiones estadisticas para poder considerarlo asi que no lo vamos a usar tal cual. Es por esto que vamos a intentar hacer algo diferente.
#
# Primero, calcularemos la distancia de mahalanobis de nuestro dataframe.

# %%
from scipy.spatial import distance
from scipy.stats import chi2

mahalanobis_distances = df.apply(lambda row: distance.mahalanobis(row, df.mean(), np.linalg.inv(df.cov())), axis=1)

# %% [markdown]
# Vamos a hacer un PCA y de las combinaciones lineales vemos que variables son lás más importantes

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=15)

pca.fit(df.drop(columns = 'price'))
components = pd.DataFrame(pca.components_).transpose()
components
# Out:
#           0         1         2         3         4         5         6   \
# 0  -0.000669  0.000261  0.012177  0.012530  0.045058 -0.061455 -0.176495
# 1   0.008079  0.003158 -0.061972 -0.064260 -0.317848  0.221399  0.536870
# 2   0.017444  0.010535 -0.073878 -0.033185 -0.820849  0.357982 -0.278266
# 3   0.002880  0.002107 -0.001934 -0.004643 -0.053424  0.061316  0.010688
# 4   0.001629 -0.000485 -0.039725 -0.014597 -0.126796  0.110067  0.208333
# 5   0.811765  0.575871 -0.090852  0.004803  0.031548 -0.005649  0.005356
# 6   0.055989  0.037741  0.684410 -0.722002 -0.047499 -0.042849 -0.027351
# 7   0.000089  0.000043  0.000227 -0.004549  0.004506  0.005383 -0.009297
# 8   0.002284 -0.002733 -0.042143 -0.039697  0.210044  0.429859 -0.675156
# 9   0.035111  0.061255  0.713097  0.673494 -0.038115  0.169493  0.035733
# 10 -0.579827  0.814163 -0.020735 -0.022311  0.002151  0.002381 -0.000509
# 11 -0.005953 -0.009935 -0.032401 -0.104018  0.281951  0.515916  0.244632
# 12 -0.006983 -0.010037 -0.020256 -0.079634  0.272220  0.563947  0.188071
# 13  0.000208 -0.000198 -0.003330 -0.002228  0.015309  0.029071 -0.048022
# 14 -0.000208  0.000198  0.003330  0.002228 -0.015309 -0.029071  0.048022
# 15  0.000017  0.000028  0.000688 -0.000200  0.005986 -0.008034 -0.011837
# 16  0.000033  0.000016  0.001986 -0.001186  0.000051 -0.000075 -0.010126
# 17 -0.000247 -0.000065  0.002973  0.006877  0.020456 -0.018739  0.011961
# 18  0.000103 -0.000009 -0.001553 -0.006086 -0.023490  0.029242 -0.006696
# 19  0.000095  0.000030 -0.004094  0.000594 -0.003003 -0.002394  0.016698
# 20  0.000023 -0.000035 -0.000996  0.002649  0.003467 -0.012092  0.004362
# 21 -0.000490 -0.000420  0.000379 -0.005472 -0.009503  0.011252 -0.002657
# 22  0.000467  0.000455  0.000617  0.002823  0.006036  0.000840 -0.001706
# 23  0.000037  0.000146  0.000517  0.000996  0.000205  0.001821 -0.004869
# 24  0.000005  0.000027  0.000606  0.001469  0.001540  0.003917  0.003339
# 25  0.000122 -0.000014 -0.003349  0.000925  0.002401  0.004336  0.017357
# 26 -0.000258 -0.000285 -0.001698 -0.004750 -0.007902  0.010283  0.004392
# 27 -0.000011 -0.000076  0.001839  0.003211 -0.000463 -0.008167 -0.008487
# 28  0.000143  0.000134  0.003015 -0.004274  0.003723 -0.007241  0.000132
# 29 -0.000038  0.000068 -0.000929  0.002423  0.000496 -0.004950 -0.011863
# 30  0.000083  0.000059  0.001696 -0.002621 -0.000048 -0.000346  0.008529
# 31  0.000083  0.000089 -0.001541 -0.000556 -0.000240 -0.000380 -0.010276
# 32 -0.000304 -0.000449 -0.004265  0.001332 -0.006691  0.003211  0.014113
# 33  0.000170  0.000231  0.004174 -0.000007  0.003845  0.000151 -0.003500
# 34 -0.000013 -0.000017  0.000090  0.000074  0.001835  0.001651  0.005062
# 35  0.000019  0.000020  0.000775 -0.000646  0.000802  0.000664 -0.002066
# 36 -0.000038  0.000068 -0.000929  0.002423  0.000496 -0.004950 -0.011863
#
#           7         8         9         10        11        12        13  \
# 0   0.086122 -0.127951 -0.549911  0.352773 -0.666671  0.135328 -0.172789
# 1  -0.644318 -0.271120 -0.076157 -0.109444 -0.194331 -0.009480 -0.032175
# 2   0.318156 -0.044632  0.079534  0.029489 -0.031037 -0.026075  0.025327
# 3  -0.102158 -0.222095 -0.417149  0.522741  0.631076  0.155907  0.136391
# 4  -0.110122  0.909425 -0.234547  0.136389 -0.011378  0.019505  0.010024
# 5   0.008526  0.000025 -0.000097 -0.001138  0.000008  0.000062 -0.001345
# 6  -0.014741  0.020134 -0.006495 -0.005723  0.000367 -0.002361  0.008165
# 7  -0.009917 -0.030621 -0.034321 -0.024819  0.018454 -0.264452 -0.307753
# 8  -0.534955  0.082703  0.018217 -0.066778  0.004715 -0.036066  0.022958
# 9  -0.029819  0.006887  0.013223  0.009176 -0.011272 -0.003570 -0.008113
# 10  0.000144  0.000382  0.000020 -0.000131 -0.000052 -0.000096  0.000192
# 11  0.161465 -0.028097  0.470137  0.548152 -0.143598 -0.001187 -0.091049
# 12  0.365404 -0.072382 -0.440750 -0.462318  0.077170  0.017221  0.089428
# 13 -0.042334  0.004789 -0.000049 -0.004455  0.000827 -0.019966 -0.029736
# 14  0.042334 -0.004789  0.000049  0.004455 -0.000827  0.019966  0.029736
# 15  0.011491  0.007452 -0.004562  0.008992 -0.017619  0.057061  0.010267
# 16 -0.004929  0.006596 -0.012725  0.004546 -0.032349  0.007302  0.053265
# 17 -0.010107 -0.086726 -0.097010  0.098707 -0.063294 -0.473771  0.225448
# 18 -0.014873  0.002501  0.076911 -0.130041  0.113041  0.590034 -0.500343
# 19  0.018418  0.070177  0.037386  0.017795  0.000221 -0.180626  0.211363
# 20  0.004275  0.032278  0.028418  0.026617  0.022432  0.058751  0.027045
# 21  0.018349  0.005231 -0.080952  0.056100  0.117152 -0.248382 -0.350119
# 22 -0.022624 -0.037509  0.052534 -0.082718 -0.139584  0.189631  0.323074
# 23  0.013121 -0.009133  0.048280 -0.000569 -0.090876  0.021390  0.021104
# 24 -0.001256 -0.001633 -0.012408  0.001150  0.017234  0.002029  0.014885
# 25 -0.008535 -0.007193 -0.017344  0.001120 -0.070078  0.102045  0.083629
# 26  0.007313  0.002243 -0.063907 -0.050618  0.116349 -0.348795 -0.434448
# 27 -0.003866  0.028659  0.046121  0.027664  0.008169  0.156366  0.183128
# 28  0.003881  0.006740  0.006922  0.025710  0.033679  0.044372  0.075093
# 29 -0.010657 -0.019683 -0.007664 -0.004457 -0.014477  0.022594  0.056608
# 30 -0.004042 -0.004072 -0.021272  0.039795  0.017129  0.032275  0.041766
# 31 -0.015114 -0.002768 -0.032605  0.050611  0.082785 -0.015581 -0.085872
# 32  0.022423  0.003262  0.012528 -0.015522 -0.027604 -0.101728 -0.076193
# 33  0.005168  0.024327  0.038149 -0.072129 -0.051860  0.049975  0.053415
# 34  0.002140  0.001353  0.000288  0.003281 -0.014737  0.011630  0.009464
# 35  0.000083 -0.002419  0.010576 -0.001579  0.008763  0.000835  0.000812
# 36 -0.010657 -0.019683 -0.007664 -0.004457 -0.014477  0.022594  0.056608
#
#           14
# 0   0.003240
# 1   0.049691
# 2  -0.005301
# 3  -0.099118
# 4  -0.052976
# 5   0.000564
# 6  -0.002164
# 7  -0.107025
# 8   0.015945
# 9   0.000330
# 10  0.000044
# 11 -0.044446
# 12  0.039626
# 13  0.007152
# 14 -0.007152
# 15 -0.045198
# 16 -0.108769
# 17  0.021911
# 18  0.002729
# 19  0.129328
# 20  0.022623
# 21  0.514043
# 22 -0.536666
# 23  0.089990
# 24 -0.001313
# 25  0.074619
# 26 -0.520983
# 27  0.215480
# 28  0.137824
# 29  0.004381
# 30 -0.000409
# 31 -0.024053
# 32 -0.133982
# 33  0.127113
# 34  0.018089
# 35  0.008861
# 36  0.004381

# %% [markdown]
# Los valores de la varianza explicada son:

# %%
values = list(pca.singular_values_/pca.singular_values_.sum())
values
# Out:
# [0.5363591633343965,
#  0.40274063385100417,
#  0.02654605182468482,
#  0.013400241162347304,
#  0.005872668535607486,
#  0.004675202996194573,
#  0.0025194770616329453,
#  0.002242795816194395,
#  0.0016250421968085336,
#  0.0009694287606541864,
#  0.0008840110386454718,
#  0.0008150373077508284,
#  0.0004916222740912361,
#  0.0004661502432392617,
#  0.00039247359674812667]

# %% [markdown]
# y esta varianza acumulada:

# %%
np.array(values).cumsum()
# Out:
# array([0.53635916, 0.9390998 , 0.96564585, 0.97904609, 0.98491876,
#        0.98959396, 0.99211344, 0.99435623, 0.99598128, 0.99695071,
#        0.99783472, 0.99864975, 0.99914138, 0.99960753, 1.        ])

# %% [markdown]
# Esto es bastante bueno ya que solo 2 vectores explica 93% de la varianza. Eso quiere decir que 53% del error lo podemos explicar con una regresion lineal (el qqplot de antes si se ve muy lineal pero las colas no nos permitieron que fuera normal).

# %%
pca_matrix = pd.DataFrame(np.transpose(pca.components_), columns=[f'PC{i}' for i in range(15)], index=df.drop(columns = 'price').columns)

pca_matrix = pca_matrix[pca_matrix.columns[:3]]
pca_matrix
# Out:
#                             PC0       PC1       PC2
# symboling             -0.000669  0.000261  0.012177
# wheelbase              0.008079  0.003158 -0.061972
# carlength              0.017444  0.010535 -0.073878
# carwidth               0.002880  0.002107 -0.001934
# carheight              0.001629 -0.000485 -0.039725
# curbweight             0.811765  0.575871 -0.090852
# enginesize             0.055989  0.037741  0.684410
# stroke                 0.000089  0.000043  0.000227
# compressionratio       0.002284 -0.002733 -0.042143
# horsepower             0.035111  0.061255  0.713097
# peakrpm               -0.579827  0.814163 -0.020735
# citympg               -0.005953 -0.009935 -0.032401
# highwaympg            -0.006983 -0.010037 -0.020256
# fueltype_diesel        0.000208 -0.000198 -0.003330
# fueltype_gas          -0.000208  0.000198  0.003330
# carbody_convertible    0.000017  0.000028  0.000688
# carbody_hardtop        0.000033  0.000016  0.001986
# carbody_hatchback     -0.000247 -0.000065  0.002973
# carbody_sedan          0.000103 -0.000009 -0.001553
# carbody_wagon          0.000095  0.000030 -0.004094
# drivewheel_4wd         0.000023 -0.000035 -0.000996
# drivewheel_fwd        -0.000490 -0.000420  0.000379
# drivewheel_rwd         0.000467  0.000455  0.000617
# enginetype_dohc        0.000037  0.000146  0.000517
# enginetype_dohcv       0.000005  0.000027  0.000606
# enginetype_l           0.000122 -0.000014 -0.003349
# enginetype_ohc        -0.000258 -0.000285 -0.001698
# enginetype_ohcf       -0.000011 -0.000076  0.001839
# enginetype_ohcv        0.000143  0.000134  0.003015
# enginetype_rotor      -0.000038  0.000068 -0.000929
# cylindernumber_eight   0.000083  0.000059  0.001696
# cylindernumber_five    0.000083  0.000089 -0.001541
# cylindernumber_four   -0.000304 -0.000449 -0.004265
# cylindernumber_six     0.000170  0.000231  0.004174
# cylindernumber_three  -0.000013 -0.000017  0.000090
# cylindernumber_twelve  0.000019  0.000020  0.000775
# cylindernumber_two    -0.000038  0.000068 -0.000929

# %% [markdown]
# Ahora veremos las 5 variables que más aportan al primer componente principal (en valor absoluto) para saber cuales son las más relevantes.

# %%
pca_matrix.sort_values(by = 'PC0', key = lambda x: abs(x)).tail(5)
# Out:
#                  PC0       PC1       PC2
# carlength   0.017444  0.010535 -0.073878
# horsepower  0.035111  0.061255  0.713097
# enginesize  0.055989  0.037741  0.684410
# peakrpm    -0.579827  0.814163 -0.020735
# curbweight  0.811765  0.575871 -0.090852

# %%
pca_matrix.sort_values(by = 'PC1', key = lambda x: abs(x)).tail(5)
# Out:
#                  PC0       PC1       PC2
# carlength   0.017444  0.010535 -0.073878
# enginesize  0.055989  0.037741  0.684410
# horsepower  0.035111  0.061255  0.713097
# curbweight  0.811765  0.575871 -0.090852
# peakrpm    -0.579827  0.814163 -0.020735

# %% [markdown]
# Vemos que en ambos vectores son casi las mismas variables por lo que podemos decir que estas son las variables importantes.
